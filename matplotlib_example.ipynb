# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-muted")

# %%
import spaces
from optimization_problems import QuadraticOptimization

# %%
ages = range(25, 36)
from random import randint
salaries = [s + randint(0, 1000) for s in range(1000, 12000, 1000)]

# %%
py_ages = range(27, 40)
py_salaries = [s + randint(0, 1000) for s in range(2000, 17000, 1200)]

# %%
# plt.plot(py_ages, py_salaries, color="r", marker="o", linewidth=3, label="Python devs")
plt.plot(py_ages, py_salaries, label="Python devs")
plt.plot(ages, salaries, color="#888888", linestyle="-.", label="All devs")
plt.title("Median salary by age")
plt.xlabel("Ages")
plt.ylabel("Median salary")
plt.legend()
plt.grid(True)
plt.tight_layout()
# plt.savefig("plot.png")
plt.show()
